# %% [markdown]
# # Meu querido notebook

# %% [markdown]
# Estou fazendo um notebook, mas mey professor disse pra não usar :)

# %% [markdown]
# ## Meu primeiro código python

# %%
print('Haja luz!')
# Out:
# Haja luz!
